# %%
using BenchmarkTools, Plots

# %%
f(x, μ, σ) = @. 1.0/√(2 * π * σ) * exp(-(x-μ)^2/(2 *σ^2))
# Out:
# f (generic function with 1 method)

# %%
xx=-5:0.1:5
# Out:
# -5.0:0.1:5.0

# %%
plot(xx, f(xx, 0.0, 1.0))
