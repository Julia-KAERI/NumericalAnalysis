# %%
using DataFrames
#using CairoMakie
# using GLMakie
using WGLMakie
# GLMakie.activate!()
WGLMakie.activate!()

# %%
t = 1:0.2:10
fig, ax = scatter(t, cos.(t))
fig
# Out:
# <div class="bonito-fragment" id="ef271c1c-b021-4429-8e88-35eef64b02d0" data-jscall-id="root">
#   <div>
#     <script src="http://localhost:9384/assets/abb111bfadc24b2c13c60abc6f946b77831acba6-Bonito.bundled.js" type="module"></script>
#     <style></style>
#     <div></div>
#   </div>
#   <div>
#     <script type="module">    Bonito.lock_loading(() => {
#         return Bonito.fetch_binary('http://localhost:9384/assets/fe68a0cae32921a2351dd9a7562341962f68c830-14948831662031406082.bin').then(msgs=> Bonito.init_session('ef271c1c-b021-4429-8e88-35eef64b02d0', msgs, 'root'));
#     })
# </script>
#     <script type="module">    import('http://localhost:9384/assets/1e8920a8e74fccabd22048f9e82b123fc3f48c08-Websocket.bundled.js').then(WS => {
#         WS.setup_connection({proxy_url: 'http://localhost:9384', session_id: 'ef271c1c-b021-4429-8e88-35eef64b02d0', compression_enabled: false})
#     })
# </script>
#     <div style="width: 100%; height: 100%" data-jscall-id="1">
# ...

# %%
df = DataFrame()
df.t = 0:0.1:10
df.N = exp.(-df.t./0.3) .+ 0.3
df.err = sqrt.(df.N)

df.N = exp.(-df.t./0.56) .+ 0.13

# %%
plot(df.t, df.N)

# %%
names(df)
# Out:
# 3-element Vector{String}:
#  "t"
#  "N"
#  "err"

# %%
step(x) = (x>0) ? 1 : 0
# Out:
# step (generic function with 1 method)

# %%
t = -6:0.01:6
f(x) = (1-abs(x))* step(1-abs(x))
# Out:
# f (generic function with 1 method)

# %%
plot(t, f.(t))

# %%
yy = @. (sin(t/2))^2/(t^2)
# Out:
# 1201-element Vector{Float64}:
#  0.0005531904631893608
#  0.0005946448013922648
#  0.0006377120840838742
#  0.0006824037160489496
#  0.0007287310664589186
#  0.0007767054680569525
#  0.0008263382163430372
#  0.0008776405687591524
#  0.0009306237438745646
#  0.000985298920571358
#  ⋮
#  0.0009306237438745646
#  0.0008776405687591524
#  0.0008263382163430372
#  0.0007767054680569525
#  0.0007287310664589186
#  0.0006824037160489496
#  0.0006377120840838742
#  0.0005946448013922648
#  0.0005531904631893608

# %%
plot(t, yy)
