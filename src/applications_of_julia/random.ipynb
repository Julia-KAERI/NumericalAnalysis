# %%
using CairoMakie, Random, Distributions

# %%
norm1 = Normal(3, 5)
x = rand(norm1, 1000000)
fig, ax = hist(x, bins=100)
#save("norm.png", fig)
fig

# %%
println("mean = $(mean(x)), std = $(std(x))")
# Out:
# mean = 3.005867724538871, std = 5.000600772359724

# %%
std(x)
# Out:
# 5.000600772359724
