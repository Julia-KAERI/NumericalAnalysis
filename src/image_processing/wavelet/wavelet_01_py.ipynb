# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img0 = cv2.imread("cameraman.tif", cv2.IMREAD_GRAYSCALE)

# %%
w = pywt.Wavelet('db15')

# %%
LL, (LH, HL, HH) = pywt.dwt2(img0, w)

# %%
plt.imshow(HH)

# %%
print(w)
# Out:
# Wavelet db15
#   Family name:    Daubechies
#   Short name:     db
#   Filters length: 30
#   Orthogonal:     True
#   Biorthogonal:   True
#   Symmetry:       asymmetric
#   DWT:            True
#   CWT:            False
