# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# plt.rcParams["text.usetex"] = True
# plt.rcParams["figure.dpi"] = 300

# %%
plt.plot([1,2,3])
plt.xlabel("$\displaystyle \int_{-\infty}^\infty e^{i\\cos \\theta}\, d \\theta$")
# Out:
# Text(0.5, 0, '$\\displaystyle \\int_{-\\infty}^\\infty e^{i\\cos \\theta}\\, d \\theta$')

# %%
plt.rcParams["text.usetex"]
