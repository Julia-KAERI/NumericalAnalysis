# %%
include("../lib/polynomial.jl")
using Plots, LaTeXStrings, BenchmarkTools

# %%
p1 = polynomial_from_roots([1.0, 3.0, 2.0, -4.0])
# Out:
# SimplePolynomial{Float64}([-24.0, 38.0, -13.0, -2.0, 1.0])

# %%
p2=lagrange_polynomial([1, 2, 3], [-3, 0, -2])
# Out:
# SimplePolynomial{Float64}([-11.0, 10.5, -2.5])

# %%
xp = 0.0:0.1:4.0
plot(xp, p2.(xp))
